# %%
import tkinter as tk
import cv2
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from PIL import Image, ImageDraw

# 데이터 로드
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 데이터 전처리
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# 모델 생성
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# 모델 컴파일 및 학습
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=128, epochs=10, verbose=1, validation_data=(x_test, y_test))

# 모델 예측 함수
def predict_digit(img):
    img = img.resize((28, 28))
    img = img.convert('L')
    img = np.array(img)
    img = img.reshape(1, 28, 28, 1)
    img = img/255.0
    res = model.predict([img])[0]
    return np.argmax(res), max(res)

# GUI 생성
window = tk.Tk()
window.title("MNIST Digit Recognizer")
canvas_width = 500
canvas_height = 500
image = Image.new("RGB", (canvas_width, canvas_height), (255, 255, 255))
draw = ImageDraw.Draw(image)

# 드로잉 영역 설정
canvas = tk.Canvas(window, width=canvas_width, height=canvas_height, bg="white")
canvas.pack()

# 드로잉 함수
def draw_digit(event):
    x1, y1 = (event.x - 10), (event.y - 10)
    x2, y2 = (event.x + 10), (event.y + 10)
    canvas.create_oval(x1, y1, x2, y2, fill="black")
    draw.ellipse([x1, y1, x2, y2], fill="black")

def clear_canvas():
    canvas.delete("all")
    draw.rectangle([0, 0, canvas_width, canvas_height], fill="white")

# 예측 함수
def predict():
    img = image.copy()
    digit, prob = predict_digit(img)
    print(f"The model predicts the digit is: {digit} with probability: {prob}")

canvas.bind("<B1-Motion>", draw_digit)
button_clear = tk.Button(window, text="Clear", command=clear_canvas)
button_clear.pack()
button_predict = tk.Button(window, text="Predict", command=predict)
button_predict.pack()

window.mainloop()
# Out:
# Epoch 1/10
# 2023-05-30 17:39:00.922786: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 469/469 [==============================] - 25s 54ms/step - loss: 0.2480 - accuracy: 0.9245 - val_loss: 0.0512 - val_accuracy: 0.9834
# Epoch 2/10
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0861 - accuracy: 0.9748 - val_loss: 0.0414 - val_accuracy: 0.9875
# Epoch 3/10
# 469/469 [==============================] - 26s 56ms/step - loss: 0.0654 - accuracy: 0.9807 - val_loss: 0.0352 - val_accuracy: 0.9880
# Epoch 4/10
# 469/469 [==============================] - 25s 53ms/step - loss: 0.0545 - accuracy: 0.9836 - val_loss: 0.0302 - val_accuracy: 0.9896
# Epoch 5/10
# 469/469 [==============================] - 24s 52ms/step - loss: 0.0464 - accuracy: 0.9854 - val_loss: 0.0293 - val_accuracy: 0.9905
# Epoch 6/10
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0404 - accuracy: 0.9870 - val_loss: 0.0313 - val_accuracy: 0.9895
# Epoch 7/10
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0353 - accuracy: 0.9886 - val_loss: 0.0315 - val_accuracy: 0.9905
# Epoch 8/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.0287 - val_accuracy: 0.9915
# Epoch 9/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0311 - accuracy: 0.9902 - val_loss: 0.0272 - val_accuracy: 0.9909
# Epoch 10/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 0.0288 - val_accuracy: 0.9921
# 1   HIToolbox                           0x00000001900d05c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001900d0188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x000000019003d8bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x00000001900d0004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x0000000189ebfd30 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x0000000189d5593c -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x0000000186972560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x0000000186a10044 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x0000000186a0ff8c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x0000000186943b64 _CFXNotificationPost + 708
# 11  Foundation                          0x000000018783338c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x0000000189ec02b4 spacesNotificationHandler + 96
# 13  SkyLight                            0x000000018b5ad214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x000000018b8d94d4 _ZN21CGSDatagramReadStream26dispatchMainQueueDatagramsEv + 228
# 15  SkyLight                            0x000000018b8d93d0 ___ZN21CGSDatagramReadStream15mainQueueWakeupEv_block_invoke + 28
# 16  libdispatch.dylib                   0x00000001867149dc _dispatch_call_block_and_release + 32
# 17  libdispatch.dylib                   0x0000000186716504 _dispatch_client_callout + 20
# 18  libdispatch.dylib                   0x0000000186724d1c _dispatch_main_queue_drain + 928
# 19  libdispatch.dylib                   0x000000018672496c _dispatch_main_queue_callback_4CF + 44
# 20  CoreFoundation                      0x00000001869bed40 __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 16
# 21  CoreFoundation                      0x000000018697c7c0 __CFRunLoopRun + 2036
# 22  CoreFoundation                      0x000000018697b878 CFRunLoopRunSpecific + 612
# 23  libtcl8.6.dylib                     0x00000001114fc7c0 Tcl_WaitForEvent + 320
# 24  libtcl8.6.dylib                     0x00000001114a9908 Tcl_DoOneEvent + 224
# 25  _tkinter.cpython-38-darwin.so       0x0000000107d11c80 _tkinter_tkapp_mainloop_impl + 252
# 26  python3.8                           0x0000000102df674c method_vectorcall_FASTCALL + 308
# 27  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 28  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 29  python3.8                           0x0000000102ded2a0 method_vectorcall + 116
# 30  python3.8                           0x0000000102ef47b4 _PyEval_EvalFrameDefault + 30664
# 31  python3.8                           0x0000000102eeb108 _PyEval_EvalCodeWithName + 736
# 32  python3.8                           0x0000000102ee5eac builtin_exec + 312
# 33  python3.8                           0x0000000102e42a00 cfunction_vectorcall_FASTCALL + 88
# 34  python3.8                           0x0000000102ef4e80 _PyEval_EvalFrameDefault + 32404
# 35  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 36  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 37  python3.8                           0x0000000102e002e0 _PyGen_Send + 188
# 38  python3.8                           0x0000000102df6ee4 method_vectorcall_O + 308
# 39  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 40  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 41  python3.8                           0x0000000102ef4e80 _PyEval_EvalFrameDefault + 32404
# 42  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 43  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 44  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 45  python3.8                           0x0000000102ded348 method_vectorcall + 284
# 46  python3.8                           0x0000000102ef99f0 _PyEval_EvalFrameDefault + 51716
# 47  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 48  python3.8                           0x0000000102ded2a0 method_vectorcall + 116
# 49  python3.8                           0x0000000102ef50fc _PyEval_EvalFrameDefault + 33040
# 50  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 51  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 52  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 53  python3.8                           0x0000000102ef60c8 _PyEval_EvalFrameDefault + 37084
# 54  python3.8                           0x0000000102e002e0 _PyGen_Send + 188
# 55  _asyncio.cpython-38-darwin.so       0x00000001058e0074 task_step_impl + 420
# 56  _asyncio.cpython-38-darwin.so       0x00000001058dfe3c task_step + 68
# 57  _asyncio.cpython-38-darwin.so       0x00000001058dfc80 task_wakeup + 132
# 58  _asyncio.cpython-38-darwin.so       0x00000001058dfb68 TaskWakeupMethWrapper_call + 160
# 59  python3.8                           0x0000000102de5f10 _PyObject_MakeTpCall + 372
# 60  python3.8                           0x0000000102f241dc context_run + 68
# 61  python3.8                           0x0000000102e42b08 cfunction_vectorcall_FASTCALL_KEYWORDS + 84
# 62  python3.8                           0x0000000102de691c PyVectorcall_Call + 472
# 63  python3.8                           0x0000000102efd8fc _PyEval_EvalFrameDefault + 67856
# 64  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 65  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 66  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 67  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 68  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 69  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 70  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 71  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 72  python3.8                           0x0000000102de7414 _PyFunction_Vectorcall + 416
# 73  python3.8                           0x0000000102ef4670 _PyEval_EvalFrameDefault + 30340
# 74  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 75  python3.8                           0x0000000102ded2a0 method_vectorcall + 116
# 76  python3.8                           0x0000000102ef47b4 _PyEval_EvalFrameDefault + 30664
# 77  python3.8                           0x0000000102eeb108 _PyEval_EvalCodeWithName + 736
# 78  python3.8                           0x0000000102ee5eac builtin_exec + 312
# 79  python3.8                           0x0000000102e42a00 cfunction_vectorcall_FASTCALL + 88
# 80  python3.8                           0x0000000102ef4e80 _PyEval_EvalFrameDefault + 32404
# 81  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 82  python3.8                           0x0000000102ef4e80 _PyEval_EvalFrameDefault + 32404
# 83  python3.8                           0x0000000102de7794 _PyFunction_Vectorcall + 1312
# 84  python3.8                           0x0000000102de691c PyVectorcall_Call + 472
# 85  python3.8                           0x0000000102f7de1c pymain_run_module + 192
# 86  python3.8                           0x0000000102f7d848 pymain_run_python + 196
# 87  python3.8                           0x0000000102f7d72c Py_RunMain + 40
# 88  python3.8                           0x0000000102db9e04 main + 56
# 89  dyld                                0x0000000186573e50 start + 2544
# 1/1 [==============================] - 0s 46ms/step
# The model predicts the digit is: 3 with probability: 0.16438156366348267
# 1/1 [==============================] - 0s 14ms/step
# The model predicts the digit is: 9 with probability: 0.9685311317443848
# 1/1 [==============================] - 0s 13ms/step
# The model predicts the digit is: 9 with probability: 0.9685311317443848
# 1/1 [==============================] - 0s 13ms/step
# The model predicts the digit is: 8 with probability: 0.5929597020149231
# 1/1 [==============================] - 0s 13ms/step
# The model predicts the digit is: 9 with probability: 0.810361385345459
# 1/1 [==============================] - 0s 12ms/step
# The model predicts the digit is: 0 with probability: 0.4825941026210785
